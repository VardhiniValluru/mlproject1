# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('DATASETAGAIN2.csv')

# Select the columns for segmentation
time_column = 'Time'
gender_column = 'Male'
age_column = 'Age'

# Segment customers based on time, gender, and age
morning_customers = data[(data[time_column] >= '08:00:00') & (data[time_column] <= '12:00:00')]
afternoon_customers = data[(data[time_column] > '12:00:00') & (data[time_column] <= '16:00:00')]
evening_customers = data[(data[time_column] > '16:00:00') & (data[time_column] <= '20:00:00')]

male_customers = data[data[gender_column] == 1]
female_customers = data[data[gender_column] == 0]

young_customers = data[data[age_column] < 30]
middle_aged_customers = data[(data[age_column] >= 30) & (data[age_column] <= 50)]
elderly_customers = data[data[age_column] > 50]

# Print the segmented customer groups
print("Morning Customers:")
print(morning_customers)
print()

print("Afternoon Customers:")
print(afternoon_customers)
print()

print("Evening Customers:")
print(evening_customers)
print()

print("Male Customers:")
print(male_customers)
print()

print("Female Customers:")
print(female_customers)
print()

print("Young Customers:")
print(young_customers)
print()

print("Middle-Aged Customers:")
print(middle_aged_customers)
print()

print("Elderly Customers:")
print(elderly_customers)
# Out:
# Morning Customers:
#       Customer id              Name  Age  Male  Annual Income(k$)  \
# 2          489441         laskshita   24     0                 75
# 3          489442          Priyusha   51     0                 80
# 7          489446      ramesh yadav   39     1                 32
# 11         489450        D Harshith   19     1                  0
# 12         489459          Nagender   36     1                 36
# ...           ...               ...  ...   ...                ...
# 1325       491081          Prasanth   57     1                 70
# 1326       490976  SOORYA PRAKASH D   29     1                 44
# 1330       491206  Maheshwar Anandh   60     1                 57
# 1332       491143      SRENIVASAN A   22     0                 10
# 1333       491337             Janet   41     0                 85
#
#       Spending Score(1-100)      Time  Quantity  \
# 2                        62  10:25 AM        10
# 3                        55  10:00 AM        10
# ...

# %%
# Segment morning customers
morning_customers = data[(data['Time'] >= '08:00:00') & (data['Time'] <= '12:00:00')]

# Count the number of males and females in the morning customers
male_count = morning_customers[morning_customers['Male'] == 1].shape[0]
female_count = morning_customers[morning_customers['Male'] == 0].shape[0]

# Compare the counts to determine if there are more males or females
if male_count > female_count:
    print("There are more males among the morning customers.")
elif male_count < female_count:
    print("There are more females among the morning customers.")
else:
    print("The number of males and females among the morning customers is equal.")
# Out:
# There are more males among the morning customers.

# %%
# Segment afternoon customers
afternoon_customers = data[(data[time_column] > '12:00:00') & (data[time_column] <= '16:00:00')]

# Count the number of males and females in the morning customers
male_count = afternoon_customers[afternoon_customers['Male'] == 1].shape[0]
female_count = afternoon_customers[afternoon_customers['Male'] == 0].shape[0]

# Compare the counts to determine if there are more males or females
if male_count > female_count:
    print("There are more males among the afternoon customers.")
elif male_count < female_count:
    print("There are more females among the afternoon customers.")
else:
    print("The number of males and females among the afternoon customers is equal.")
# Out:
# There are more females among the afternoon customers.

# %%
# Segment afternoon customers

evening_customers = data[(data[time_column] > '16:00:00') & (data[time_column] <= '20:00:00')]

# Count the number of males and females in the morning customers
male_count = evening_customers[evening_customers['Male'] == 1].shape[0]
female_count = evening_customers[evening_customers['Male'] == 0].shape[0]

# Compare the counts to determine if there are more males or females
if male_count > female_count:
    print("There are more males among the evening customers.")
elif male_count < female_count:
    print("There are more females among the evening customers.")
else:
    print("The number of males and females among the evening customers is equal.")
# Out:
# There are more males among the evening customers.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv('DATASETAGAIN2.csv')

# Segment morning customers
morning_customers = data[(data['Time'] >= '08:00:00') & (data['Time'] <= '12:00:00')]

# Count the number of males and females in the morning customers
male_count = morning_customers[morning_customers['Male'] == 1].shape[0]
female_count = morning_customers[morning_customers['Male'] == 0].shape[0]

# Prepare data for visualization
gender_labels = ['Male', 'Female']
gender_counts = [male_count, female_count]

# Create a bar plot
plt.bar(gender_labels, gender_counts)
plt.title('Segmentation of Morning Customers by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
# Read the CSV file
data = pd.read_csv('DATASETAGAIN2.csv')

# Segment afternoon customers
afternoon_customers = data[(data['Time'] > '12:00:00') & (data['Time'] <= '16:00:00')]

# Count the number of males and females in the afternoon customers
male_count = afternoon_customers[afternoon_customers['Male'] == 1].shape[0]
female_count = afternoon_customers[afternoon_customers['Male'] == 0].shape[0]

# Prepare data for visualization
gender_labels = ['Male', 'Female']
gender_counts = [male_count, female_count]

# Create a bar plot
plt.bar(gender_labels, gender_counts)
plt.title('Segmentation of Afternoon Customers by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file
data = pd.read_csv('DATASETAGAIN2.csv')

# Segment evening customers
evening_customers = data[(data['Time'] > '16:00:00') & (data['Time'] <= '20:00:00')]

# Count the number of males and females in the evening customers
male_count = evening_customers[evening_customers['Male'] == 1].shape[0]
female_count = evening_customers[evening_customers['Male'] == 0].shape[0]

# Prepare data for visualization
gender_labels = ['Male', 'Female']
gender_counts = [male_count, female_count]

# Create a bar plot
plt.bar(gender_labels, gender_counts)
plt.title('Segmentation of Evening Customers by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')

# Display the plot
plt.show()

# %%
dataset= pd.read_csv("DATASETAGAIN2.csv")

# %%
dataset.head()
# Out:
#    Customer id             Name  Age  Male  Annual Income(k$)  \
# 0       489439    Chandu Tamire   23     1                 49
# 1       489440  Rahul siddarth    16     1                  0
# 2       489441        laskshita   24     0                 75
# 3       489442         Priyusha   51     0                 80
# 4       489443           Tharun   21     1                 15
#
#    Spending Score(1-100)      Time  Quantity     item1        item2  \
# 0                     70   8:57 AM        10      Milk       Butter
# 1                     45   3:09 PM         7  Deodrant   Hair serum
# 2                     62  10:25 AM        10    cheese         Eggs
# 3                     55  10:00 AM        10      Milk        Bread
# 4                     12   2:46 PM         2     Bread    Fruit jam
#
#                  item3                item4                item5  \
# 0             Deodrant   Colgate toothpaste   Colgate toothbrush
# ...

# %%
dataset.tail()
# Out:
#       Customer id              Name  Age  Male  Annual Income(k$)  \
# 1330       491206  Maheshwar Anandh   60     1                 57
# 1331       491358              Ravi   34     1                 21
# 1332       491143      SRENIVASAN A   22     0                 10
# 1333       491337             Janet   41     0                 85
# 1334       490963         Madhura k   51     0                 43
#
#       Spending Score(1-100)      Time  Quantity  \
# 1330                     65  10:32 AM         7
# 1331                     52    9:40AM         7
# 1332                     33  11:55 AM         3
# 1333                     60   10:25AM         6
# 1334                     28   6:14 PM         4
#
#                               item1                 item2        item3  \
# 1330                          Onion               Brinjal         Milk
# 1331                 Pillsbury atta      Jeera samba rice        onion
# ...

# %%
dataset.describe
# Out:
# <bound method NDFrame.describe of       Customer id              Name  Age  Male  Annual Income(k$)  \
# 0          489439     Chandu Tamire   23     1                 49
# 1          489440   Rahul siddarth    16     1                  0
# 2          489441         laskshita   24     0                 75
# 3          489442          Priyusha   51     0                 80
# 4          489443            Tharun   21     1                 15
# ...           ...               ...  ...   ...                ...
# 1330       491206  Maheshwar Anandh   60     1                 57
# 1331       491358              Ravi   34     1                 21
# 1332       491143      SRENIVASAN A   22     0                 10
# 1333       491337             Janet   41     0                 85
# 1334       490963         Madhura k   51     0                 43
#
#       Spending Score(1-100)      Time  Quantity  \
# 0                        70   8:57 AM        10
# ...

# %%
X = dataset.iloc[:,[2,5,7]].values

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X)
print(y_kmeans)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [2 1 2 ... 1 0 0]

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'pink', label = 'Cluster 1')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'violet', label = 'Cluster 2')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'orange', label = 'Cluster 3')


plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of customers')
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.legend()
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
labels = kmeans.labels_
silhouette_avg = silhouette_score(X,labels)
print("The silhouette score is ",silhouette_avg)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# The silhouette score is  0.401456908009059

# %%
# !pip install apyori
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#importing dataset
dataset = pd.read_csv('DATASETAGAIN2.csv')

# %%
columns = ['item1', 'item2', 'item3', 'item4', 'item5', 'item6', 'item7', 'item8', 'item9', 'item10']  # Add more column names if needed

for column in columns:
    counts = dataset[column].value_counts().head(10)
    print(counts)
# Out:
# Milk          195
# Bread         102
# Deodrant       59
# Onion          56
# Tomato         51
# Coconut        49
# Ghee           48
# soya sauce     47
# Mung dal       37
# Rice           36
# Name: item1, dtype: int64
#  Bread          141
#  Fruit jam       78
#  Wheat flour     59
# Milk             53
# Mango            51
# Onion            51
# Brinjal          48
#  Butter          34
#  Rice            30
#  Tata salt       29
# Name: item2, dtype: int64
#  Fruit jam                        93
# Milk                              54
# Tomato                            54
# Green chill                       48
#  Butter                           45
#  Wheat flour                      39
#  Rice                             38
# Britannia Marie gold\n biscuit    37
#  Deodrant                         32
#  Tata salt                        30
# Name: item3, dtype: int64
# Milk              51
#  Butter           51
# Apple             48
# Cabbage           43
# ...

# %%
item1_counts = dataset['item1'].value_counts()
item2_counts = dataset['item2'].value_counts()
item3_counts = dataset['item3'].value_counts()
item4_counts = dataset['item4'].value_counts()
item5_counts = dataset['item5'].value_counts()
item6_counts = dataset['item6'].value_counts()
item7_counts = dataset['item7'].value_counts()
item8_counts = dataset['item8'].value_counts()
item9_counts = dataset['item9'].value_counts()
item10_counts = dataset['item10'].value_counts()

sum_counts = item1_counts.add(item2_counts, fill_value=0).add(item3_counts, fill_value=0).add(item4_counts, fill_value=0).add(item5_counts, fill_value=0).add(item6_counts, fill_value=0).add(item7_counts, fill_value=0).add(item8_counts, fill_value=0).add(item9_counts, fill_value=0).add(item10_counts, fill_value=0)
sum_counts = sum_counts.sort_values(ascending=False)
sum_counts.head(50)
# Out:
# Milk                                  365.0
#  Onion                                208.0
#  Eggs                                 192.0
#  Tomato                               178.0
#  Tata salt                            176.0
#  Fruit jam                            172.0
#  Wheat flour                          166.0
#  Butter                               153.0
#  shampoo                              146.0
#  Bread                                144.0
#  Pepper                               137.0
#  Paneer                               134.0
#  Rice                                 127.0
#  Hair Conditioner                     120.0
#  Britannia GoodDay cashew biscuits    119.0
#  Potato                               119.0
# Onion                                 119.0
#  Sugar                                118.0
#  Deodrant                             117.0
# Bread                                 117.0
#  Hair oil                             113.0
# ...

# %%
#fill empty spaces with 0
dataset.fillna(0,inplace=True)

# %%
dataset = pd.read_csv('DATASETAGAIN2.csv', header = None)
transactions = []
for i in range(1, 1335):
    transactions.append([str(dataset.values[i,j]) for j in range(8,18)])

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.03, min_confidence = 0.1, min_lift = 3, min_length = 3)

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({' Butter', ' Bread'}), support=0.047976011994003, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bread'}), items_add=frozenset({' Butter'}), confidence=0.4444444444444444, lift=3.875090777051561), OrderedStatistic(items_base=frozenset({' Butter'}), items_add=frozenset({' Bread'}), confidence=0.4183006535947712, lift=3.8750907770515606)]),
#  RelationRecord(items=frozenset({' Bread', ' Cheese'}), support=0.03673163418290855, ordered_statistics=[OrderedStatistic(items_base=frozenset({' Bread'}), items_add=frozenset({' Cheese'}), confidence=0.3402777777777778, lift=4.539305555555556), OrderedStatistic(items_base=frozenset({' Cheese'}), items_add=frozenset({' Bread'}), confidence=0.49, lift=4.539305555555555)]),
# ...

# %%
#dataset_results = pd.DataFrame(results)

# %%
#def inspect(results):
    #lhs         = [tuple(result[2][0][0])[0] for result in results]
    #rhs         = [tuple(result[2][0][1])[0] for result in results]
    #supports    = [result[1] for result in results]
    #confidences = [result[2][0][2] for result in results]
    #lifts       = [result[2][0][3] for result in results] 
    #return list(zip(lhs, rhs, supports, confidences, lifts))
#resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
#resultsinDataFrame
# Out:
#     Left Hand Side Right Hand Side   Support  Confidence       Lift
# 0            Bread          Butter  0.047976    0.444444   3.875091
# 1            Bread          Cheese  0.036732    0.340278   4.539306
# 2            Bread       Fruit jam  0.068216    0.631944   4.901244
# 3            Bread            Ghee  0.033733    0.312500   4.581044
# 4            Bread            Milk  0.106447    0.986111   3.633901
# ..             ...             ...       ...         ...        ...
# 225        Cabbage             nan  0.031484    0.976744  27.145349
# 226        Cabbage             nan  0.030735    0.953488  27.062840
# 227        Cabbage             nan  0.030735    0.953488  27.062840
# 228        Coconut             nan  0.035232    0.870370  24.703704
# 229        Cabbage             nan  0.030735    0.953488  27.062840
#
# [230 rows x 5 columns]

# %%
#resultsinDataFrame.nlargest(n = 20, columns = 'Lift')
# Out:
#     Left Hand Side Right Hand Side   Support  Confidence       Lift
# 59     Green chill      Naga Maida  0.033733    0.937500  27.791667
# 134    Green chill      Naga Maida  0.033733    0.937500  27.791667
# 137    Green chill          Tomato  0.032984    0.916667  27.791667
# 138    Green chill             nan  0.033733    0.937500  27.791667
# 192    Green chill          Tomato  0.032984    0.916667  27.791667
# 193    Green chill             nan  0.033733    0.937500  27.791667
# 195    Green chill          Tomato  0.032984    0.916667  27.791667
# 221    Green chill             nan  0.032984    0.916667  27.791667
# 102        Cabbage        Cucumber  0.031484    0.976744  27.145349
# 104        Cabbage         Coconut  0.031484    0.976744  27.145349
# 105        Cabbage          Tomato  0.031484    0.976744  27.145349
# 108        Cabbage        Cucumber  0.031484    0.976744  27.145349
# 114        Cabbage          Tomato  0.031484    0.976744  27.145349
# ...

# %%
support = dataset_results.support

# %%
first_values = []
second_values = []
third_values = []
fourth_values = []

# %%
for i in range(dataset_results.shape[0]):
    single_list = dataset_results['ordered_statistics'][i][0]
    first_values.append(list(single_list[0]))
    second_values.append(list(single_list[1]))
    third_values.append(single_list[2])
    fourth_values.append(single_list[3])

# %%
lhs = pd.DataFrame(first_values)
rhs= pd.DataFrame(second_values)
confidence=pd.DataFrame(third_values,columns=['Confidence'])
lift=pd.DataFrame(fourth_values,columns=['lift'])

# %%
dataset_final = pd.concat([lhs,rhs,support,confidence,lift], axis=1)
dataset_final
# Out:
#            0           0       1       2        3         4         5  \
# 0      Bread      Butter    None    None     None      None      None
# 1      Bread      Cheese    None    None     None      None      None
# 2      Bread   Fruit jam    None    None     None      None      None
# 3      Bread        Ghee    None    None     None      None      None
# 4      Bread        Milk    None    None     None      None      None
# ..       ...         ...     ...     ...      ...       ...       ...
# 225  Cabbage         nan  Potato  Tomato  Coconut  Cucumber      None
# 226  Cabbage         nan   Onion  Potato   Tomato   Coconut      None
# 227  Cabbage         nan   Onion  Potato   Tomato  Cucumber      None
# 228  Coconut         nan   Onion  Potato   Tomato  Cucumber      None
# 229  Cabbage         nan   Onion  Potato   Tomato   Coconut  Cucumber
#
#       support  Confidence       lift
# 0    0.047976    0.444444   3.875091
# 1    0.036732    0.340278   4.539306
# ...

# %%
dataset_final.fillna(value=' ', inplace=True)

# %%
dataset_final.columns = ['lhs','1','2','3','4','5','rhs','support','confidence','lift']

# %%
dataset_final['lhs'] = dataset_final['lhs']+str(", ")+dataset_final['1'] +str(", ")+dataset_final['2']

# %%
dataset_final['rhs']= dataset_final['rhs'] +str(", ")+dataset_final['3'] +str(", ")+dataset_final['4'] +str(", ")+dataset_final['5']

# %%
dataset_final.drop(columns=['1','2'],inplace=True)

# %%
dataset_final.drop(columns=['3','4','5'],inplace=True)

# %%
dataset_final.head(5)
# Out:
#                      lhs         rhs   support  confidence      lift
# 0      Bread,  Butter,     ,  ,  ,    0.047976    0.444444  3.875091
# 1      Bread,  Cheese,     ,  ,  ,    0.036732    0.340278  4.539306
# 2   Bread,  Fruit jam,     ,  ,  ,    0.068216    0.631944  4.901244
# 3        Bread,  Ghee,     ,  ,  ,    0.033733    0.312500  4.581044
# 4         Bread, Milk,     ,  ,  ,    0.106447    0.986111  3.633901

# %%
dataset_final.tail()
# Out:
#                       lhs                                rhs   support  \
# 225  Cabbage, nan, Potato        , Tomato, Coconut, Cucumber  0.031484
# 226   Cabbage, nan, Onion          , Potato, Tomato, Coconut  0.030735
# 227   Cabbage, nan, Onion         , Potato, Tomato, Cucumber  0.030735
# 228   Coconut, nan, Onion         , Potato, Tomato, Cucumber  0.035232
# 229   Cabbage, nan, Onion  Cucumber, Potato, Tomato, Coconut  0.030735
#
#      confidence       lift
# 225    0.976744  27.145349
# 226    0.953488  27.062840
# 227    0.953488  27.062840
# 228    0.870370  24.703704
# 229    0.953488  27.062840
